# %%
#!pip install matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df.head()
# Out:
#                value
# 2019-06-07  1.982099
# 2019-06-08 -0.617074
# 2019-06-09  2.121831
# 2019-06-10  1.811985
# 2019-06-11  0.339917

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
pd.date_range('2019-06-07', periods = 1000)[:1]
# Out:
# DatetimeIndex(['2019-06-07'], dtype='datetime64[ns]', freq='D')

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07  1.445386
# 2019-06-08  3.413259
# 2019-06-09  3.654059
# 2019-06-10  3.030509
# 2019-06-11  2.302357

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07    0.106998
# 2019-06-08   -0.829206
# 2019-06-09   -2.097881
# 2019-06-10   -4.968519
# 2019-06-11   -6.012865
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,5))
plt.plot(ts);

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
#ts[1].plot(kind = 'bar')
ts[:10].plot(kind = 'bar');
ts.plot(kind = 'line');

# %%
df = iris.drop(['species'], axis = 1)

# %%
a = df.iloc[10]
a
# Out:
# sepal_length    5.4
# sepal_width     3.7
# petal_length    1.5
# petal_width     0.2
# Name: 10, dtype: float64

# %%
a.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.set()
a.plot.bar();

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'][:10].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0 -0.045979 -1.773434  1.169549 -1.142597
# 1 -0.193762 -1.279065  1.295861 -0.556532
# 2 -0.923681 -0.659695 -0.745608 -0.424036
# 3  0.671055 -2.234462  0.987771 -0.558549
# 4  0.232573 -0.704198  1.647506  1.863060
# 5 -0.198031 -0.101930 -0.060875 -1.479004
# 6 -0.977626 -0.556604  1.016566  0.085363
# 7  0.214684 -3.270843  0.270356  0.220090
# 8 -0.504609 -0.035215  0.737200 -0.273154
# 9  1.940671 -1.132867  0.071629  0.552049

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
iris.plot.hist()
iris.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = True, bins = 40)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
print(iris['sepal_width'][:5])

iris['sepal_width'].diff()[:5]
# Out:
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# Name: sepal_width, dtype: float64
# 0    NaN
# 1   -0.5
# 2    0.2
# 3   -0.1
# 4    0.5
# Name: sepal_width, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 20)

# %%
titanic.fare.plot(kind = "line", figsize=(15,5), color="grey")
max(titanic.fare)
plt.ylabel("Fare")
# Out:
# Text(0, 0.5, 'Fare')

# %%
titanic.survived.hist(color="r");

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

newdf = titanic.select_dtypes(include=numerics)
newdf
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3   NaN      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
newdf.diff().hist(color = '#EC7063', alpha = 0.7, figsize=(10,10));

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c="darkgreen")

# %%
#df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')
#plt.scatter("survived","pclass")
#!pip install --upgrade matplotlib
cm = plt.cm.get_cmap('plasma')
sc=plt.scatter('sepal_length', 'petal_length', c = "petal_length", data=iris,vmin=0, vmax=12, s=35, cmap=cm)
plt.colorbar(sc)
plt.show()

# %%
import matplotlib.pyplot as plt
cm = plt.cm.get_cmap('plasma')
x =[1,4,2,5,2,7,7,3,2,1,4],
y= [1,4,2,5,2,7,7,3,2,1,4]
sc=plt.scatter(x, y, c=y,vmin=0, vmax=10, s=35, cmap=cm)
plt.colorbar(sc)
plt.show()

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
#df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
#df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
df =iris

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 10, C = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10),subplots=True);

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f') #2decimal points
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
a = [0.1]*4
pd.Series(a)
a
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()
series
# Out:
# a    0.2
# b    0.2
# c    0.2
# d    0.2
# e    0.2
# Name: Pie Plot, dtype: float64

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
ts.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')

# %%
ts.plot(style = 'r-', label = 'Series', legend = True)
# Out:
# <AxesSubplot:>

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width]
# Index: []

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)
# Out:
# <AxesSubplot:label='8269f273-852d-4c0c-af0f-ae066e3b882f'>

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
plt.figure(figsize=(150,200));
df.plot(subplots = True,figsize=(10,20));

# %%
df.plot(subplots = True, sharex = False, layout = (2,2), figsize = (16,8))
plt.tight_layout()

# %%
from descartes import PolygonPatch

# %%
map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
map_df.plot()

# %%
import geopandas as gpd

# %%
map_df
# Out:
#                       NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER  \
# 0     Kingston upon Thames  E09000021   3726.117       0.000         F
# 1                  Croydon  E09000008   8649.441       0.000         F
# 2                  Bromley  E09000006  15013.487       0.000         F
# 3                 Hounslow  E09000018   5658.541      60.755         F
# 4                   Ealing  E09000009   5554.428       0.000         F
# 5                 Havering  E09000016  11445.735     210.763         F
# 6               Hillingdon  E09000017  11570.063       0.000         F
# 7                   Harrow  E09000015   5046.330       0.000         F
# 8                    Brent  E09000005   4323.270       0.000         F
# 9                   Barnet  E09000003   8674.837       0.000         F
# 10                 Lambeth  E09000022   2724.940      43.927         T
# 11               Southwark  E09000028   2991.340     105.139         T
# ...
